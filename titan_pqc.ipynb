# %%
# 1. Scarica il codice ufficiale da GitHub
# !git clone https://github.com/catinoandrea-lgtm/TITAN-PQC.git

# 2. Entra nella cartella del progetto
# %cd TITAN-PQC

# 3. Compila usando il Makefile (rileverà in automatico AVX2 su Colab)
# !make clean && make

# 4. Esegui il benchmark
# !./titan_avx2_bench
# Out:
# Cloning into 'TITAN-PQC'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 60 (delta 10), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (60/60), 29.73 KiB | 1.29 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# /content/TITAN-PQC/TITAN-PQC
# rm -f titan_avx2_bench titan_m1_bench titan_android_bench
# gcc -O3 -std=gnu11 -Wall -Wextra -mavx2 -mfma -march=native titan_bench.c titan_avx2.c titan_constants.c -o titan_avx2_bench -lm
# => Build completata! Esegui: ./titan_avx2_bench
# ...
#  TITAN-KEM-512 | OFFICIAL AVX2 BENCHMARK v2
# ...
# Forward-Inverse Roundtrip : PASS
# NTT Forward              : 3.795 us
# NTT Inverse              : 1.813 us
# Pointwise Mul            : 0.015 us
# Keccakx4 Matrix A        : 1.609 us
# ...
